# %%
import pandas as pd

# %%
# Read csv file and display first 10 rows
pd.read_csv('PRODUCT.csv').head(10)
# Out:
#    Record_ID    Month                         Product_Name         Category  \
# 0       1000  2025-04                     Air Purifier Pro  Home Appliances
# 1       1001  2025-08  Wireless Noise-Canceling Headphones      Electronics
# 2       1002  2025-01            Stainless Steel Air Fryer          Kitchen
# 3       1003  2025-09                 Ergonomic Desk Chair        Furniture
# 4       1004  2025-10  Wireless Noise-Canceling Headphones      Electronics
# 5       1005  2025-02                 Ergonomic Desk Chair        Furniture
# 6       1006  2025-12                    Gaming Laptop Pro        Computers
# 7       1007  2025-08                     4K OLED Smart TV      Electronics
# 8       1008  2025-09                     Air Purifier Pro  Home Appliances
# 9       1009  2025-10                     Air Purifier Pro  Home Appliances
#
#    Original_Price_USD  Discount_Percent  Effective_Price_USD  \
# 0              229.92                15               195.43
# ...

# %%
# Read multi-sheet excel and access one specific sheet
pd.read_excel('company_data.xlsx',sheet_name='Employees')
# Out:
#   Employee_ID           Name Department  Salary_USD
# 0         E01    Alice Smith      Sales       75000
# 1         E02      Bob Jones         IT       82000
# 2         E03  Charlie Brown  Marketing       68000
# 3         E04   Diana Prince      Sales       78000
# 4         E05    Evan Wright         HR       62000

# %%
# Read json file and convert to table using json normalize
import json
with open('PRODUCT.json', 'r') as jsonfile:
    data = json.load(jsonfile)

pd.json_normalize(data)
# Out:
#      Record_ID    Month                         Product_Name         Category  \
# 0         1000  2025-04                     Air Purifier Pro  Home Appliances
# 1         1001  2025-08  Wireless Noise-Canceling Headphones      Electronics
# 2         1002  2025-01            Stainless Steel Air Fryer          Kitchen
# 3         1003  2025-09                 Ergonomic Desk Chair        Furniture
# 4         1004  2025-10  Wireless Noise-Canceling Headphones      Electronics
# ..         ...      ...                                  ...              ...
# 145       1145  2025-04  Wireless Noise-Canceling Headphones      Electronics
# 146       1146  2026-02            Stainless Steel Air Fryer          Kitchen
# 147       1147  2025-02                     4K OLED Smart TV      Electronics
# 148       1148  2025-11           Portable Bluetooth Speaker            Audio
# 149       1149  2025-06           Portable Bluetooth Speaker            Audio
#
# ...
